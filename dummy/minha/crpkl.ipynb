# %%
import pandas as pd
df = pd.read_csv('main_data.csv')

# %%
df['FCLTY_NM'].unique()
# Out:
# array(['9.81파크', '강창학종합경기장', '갤러리2중선농원', '건강과성박물관', '고흐의정원', '교래자연휴양림',
#        '국립제주박물관', '국제리더스클럽', '그리스신화박물관', '금능석물원', '금능해수욕장', '기당미술관',
#        '김녕미로공원', '김녕요트투어', '김녕해수욕장', '김만덕기념관', '김영갑갤러리두모악', '남원큰엉해변',
#        '너븐숭이4.3기념관', '노형근린공원', '대정현역사자료전시관', '더마파크', '돌하르방미술관', '라온GC',
#        '만장굴', '메이즈랜드', '무민랜드제주', '바이나흐튼크리스마스박물관', '방림원', '본태박물관',
#        '붉은오름자연휴양림', '블랙스톤제주CC', '비자림', '빛의벙커', '사계해안', '사라봉공원', '새별오름',
#        '새별프렌즈', '샤인빌파크CC', '서귀포치유의숲', '서복전시관', '서프라이즈테마파크', '선녀와나무꾼테마공원',
#        '섭지코지', '성산일출봉', '세계술박물관', '세리월드', '소암기념관', '소인국테마파크',
#        '수목원테마파크아이스뮤지엄', '숨도', '스카이워터쇼', '신양섭지해수욕장', '신창풍차해안도로',
#        '아라리오뮤지엄동문모텔2', '아프리카박물관', '애월해안도로', '에코랜드테마파크', '여미지식물원',
#        '오설록티뮤지엄', '우도봉', '웅지승마센터', '윈드1947카트테마파크', '이중섭미술관', '일출랜드',
#        '절물자연휴양림', '제주4.3평화공원', '제주4.3평화공원제주4.3평화기념관', '제주곶자왈도립공원',
#        '제주국제평화센터', '제주도립김창열미술관', '제주도립미술관', '제주돌문화공원', '제주러브랜드', '제주민속촌',
#        '제주불빛정원', '제주시민속오일시장', '제주신화월드', '제주아트서커스', '제주영상문화산업진흥원',
# ...

# %%
df2 = pd.read_csv('./minha/data/df.csv')
df2
# Out:
#     Unnamed: 0         place                         address  \
# 0            0        김녕해수욕장             제주특별자치도 제주시 구좌읍 김녕리
# 1            1      에코랜드테마파크        제주특별자치도 제주시 조천읍 남조로 2020
# 2            2         카멜리아힐      제주특별자치도 서귀포시 안덕면 상창리 557-3
# 3            3          섭지코지          제주특별자치도 서귀포시 성산읍 섭지코지로
# 4            4       절물자연휴양림         제주특별자치도 제주시 한경면 절물로 168
# 5            5        9.81파크         제주특별자치도 서귀포시 안덕면 창고길 27
# 6            6      훈데르트바서파크        제주특별자치도 제주시 한림읍 금능리 1961
# 7            7    선녀와나무꾼테마공원         제주특별자치도 제주시 한림읍 귀덕리 370
# 8            8     서프라이즈테마파크         제주특별자치도 제주시 한림읍 한림로 220
# 9            9          더마파크            제주특별자치도 서귀포시 색달로 213
# 10          10        김만덕기념관              제주특별자치도 제주시 도남로 53
# 11          11      그리스신화박물관        제주특별자치도 서귀포시 남원읍 태위로 407
# 12          12       국립제주박물관           제주특별자치도 제주시 일도2동 2490
# 13          13    너븐숭이4.3기념관      제주특별자치도 제주시 조천읍 4.3기념관로 55
# ...

# %%
df2['place'].unique
# Out:
# <bound method Series.unique of 0           김녕해수욕장
# 1         에코랜드테마파크
# 2            카멜리아힐
# 3             섭지코지
# 4          절물자연휴양림
# 5           9.81파크
# 6         훈데르트바서파크
# 7       선녀와나무꾼테마공원
# 8        서프라이즈테마파크
# 9             더마파크
# 10          김만덕기념관
# 11        그리스신화박물관
# 12         국립제주박물관
# 13      너븐숭이4.3기념관
# 14       제주항공우주박물관
# 15         제주도립미술관
# 16         제주현대미술관
# 17    ICC제주국제컨벤션센터
# 18          남원큰엉해변
# 19      선녀와나무꾼테마공원
# Name: place, dtype: object>

# %%
# Re-import pandas to ensure previous cells are correctly setting up the environment
import pandas as pd

# Create initial DataFrame template with just the first 10 locations and their details as a start
initial_data = {
    "Unnamed: 0": range(21, 31),
    "place": [
        '9.81파크', '강창학종합경기장', '갤러리2중선농원', '건강과성박물관', '고흐의정원', '교래자연휴양림',
        '국립제주박물관', '국제리더스클럽', '그리스신화박물관', '금능석물원'
    ],
    "address": [""] * 10,  # Addresses are left empty as requested
    "description": [""] * 10,
    "link": [
        "https://www.981park.com/", "https://www.981park.com/", "https://www.981park.com/", "http://www.sexmuseum.or.kr/", "https://goghs-garden.modoo.at/",
        "https://www.visitjeju.net/kr/detail/view?contentsid=CONT_000000000500497", "https://jeju.museum.go.kr/", "", 
        "http://www.greekmythology.co.kr/", "https://www.981park.com/"
    ],
    "photo": [""] * 10
}

# Convert initial dictionary into a DataFrame
df_initial = pd.DataFrame(initial_data)

df_initial
# Out:
#    Unnamed: 0     place address description  \
# 0          21    9.81파크
# 1          22  강창학종합경기장
# 2          23  갤러리2중선농원
# 3          24   건강과성박물관
# 4          25     고흐의정원
# 5          26   교래자연휴양림
# 6          27   국립제주박물관
# 7          28   국제리더스클럽
# 8          29  그리스신화박물관
# 9          30     금능석물원
#
#                                                 link photo
# 0                           https://www.981park.com/
# 1
# 2
# 3                        http://www.sexmuseum.or.kr/
# 4                     https://goghs-garden.modoo.at/
# 5  https://www.visitjeju.net/kr/detail/view?conte...
# 6                         https://jeju.museum.go.kr/
# 7
# 8                   http://www.greekmythology.co.kr/
# 9

# %%
# Prepare the next batch of 10 locations and their details for the DataFrame
next_batch_data = {
    "Unnamed: 0": range(31, 41),
    "place": [
        '금능해수욕장', '기당미술관', '김녕미로공원', '김녕요트투어', '김녕해수욕장', '김만덕기념관',
        '김영갑갤러리두모악', '남원큰엉해변', '너븐숭이4.3기념관', '노형근린공원'
    ],
    "address": [""] * 10,  # Addresses are left empty as requested
    "description": [""] * 10,
    "link": [
        "", "https://www.seogwipo.go.kr/museum/", "http://www.mazepark.com/", "http://www.gnyacht.co.kr/",
        "https://www.visitjeju.net/kr/detail/view?contentsid=CONT_000000000500497", "http://www.mandukmuseum.or.kr/",
        "http://www.dumoak.com/", "https://www.visitjeju.net/kr/detail/view?contentsid=CONT_000000000500497",
        "http://www.43jeju.net/", ""
    ],
    "photo": [""] * 10
}

# Convert this batch into a DataFrame and append to the initial DataFrame
df_next_batch = pd.DataFrame(next_batch_data)
df_combined = pd.concat([df_initial, df_next_batch], ignore_index=True)

df_combined
# Out:
#     Unnamed: 0       place address description  \
# 0           21      9.81파크
# 1           22    강창학종합경기장
# 2           23    갤러리2중선농원
# 3           24     건강과성박물관
# 4           25       고흐의정원
# 5           26     교래자연휴양림
# 6           27     국립제주박물관
# 7           28     국제리더스클럽
# 8           29    그리스신화박물관
# 9           30       금능석물원
# 10          31      금능해수욕장
# 11          32       기당미술관
# 12          33      김녕미로공원
# 13          34      김녕요트투어
# 14          35      김녕해수욕장
# 15          36      김만덕기념관
# 16          37   김영갑갤러리두모악
# 17          38      남원큰엉해변
# 18          39  너븐숭이4.3기념관
# 19          40      노형근린공원
#
#                                                  link photo
# 0                            https://www.981park.com/
# 1
# 2
# 3                         http://www.sexmuseum.or.kr/
# 4                      https://goghs-garden.modoo.at/
# 5   https://www.visitjeju.net/kr/detail/view?conte...
# 6                          https://jeju.museum.go.kr/
# 7
# ...

# %%
# Prepare the next batch of 10 locations and their details for the DataFrame
next_batch_data_2 = {
    "Unnamed: 0": range(41, 51),
    "place": [
        '대정현역사자료전시관', '더마파크', '돌하르방미술관', '라온GC', '만장굴', '메이즈랜드',
        '무민랜드제주', '바이나흐튼크리스마스박물관', '방림원', '본태박물관'
    ],
    "address": [""] * 10,  # Addresses are left empty as requested
    "description": [""] * 10,
    "link": [
        "", "http://www.themapark.com/", "http://www.dolharbang.or.kr/", "http://www.raon.co.kr/",
        "https://www.visitjeju.net/kr/detail/view?contentsid=CONT_000000000500497", "http://www.mazeland.co.kr/",
        "http://www.moominlandjeju.com/", "http://www.xmasmuseum.net/", "http://www.banglimwon.com/",
        "http://www.bontemuseum.com/"
    ],
    "photo": [""] * 10
}

# Convert this batch into a DataFrame and append to the combined DataFrame
df_next_batch_2 = pd.DataFrame(next_batch_data_2)
df_combined = pd.concat([df_combined, df_next_batch_2], ignore_index=True)

df_combined
# Out:
#     Unnamed: 0          place address description  \
# 0           21         9.81파크
# 1           22       강창학종합경기장
# 2           23       갤러리2중선농원
# 3           24        건강과성박물관
# 4           25          고흐의정원
# 5           26        교래자연휴양림
# 6           27        국립제주박물관
# 7           28        국제리더스클럽
# 8           29       그리스신화박물관
# 9           30          금능석물원
# 10          31         금능해수욕장
# 11          32          기당미술관
# 12          33         김녕미로공원
# 13          34         김녕요트투어
# 14          35         김녕해수욕장
# 15          36         김만덕기념관
# 16          37      김영갑갤러리두모악
# 17          38         남원큰엉해변
# 18          39     너븐숭이4.3기념관
# 19          40         노형근린공원
# 20          41     대정현역사자료전시관
# 21          42           더마파크
# 22          43        돌하르방미술관
# 23          44           라온GC
# 24          45            만장굴
# 25          46          메이즈랜드
# 26          47         무민랜드제주
# 27          48  바이나흐튼크리스마스박물관
# 28          49            방림원
# ...

# %%
# Prepare the next batch of 10 locations and their details for the DataFrame
next_batch_data_3 = {
    "Unnamed: 0": range(51, 61),
    "place": [
        '붉은오름자연휴양림', '블랙스톤제주CC', '비자림', '빛의벙커', '사계해안', '사라봉공원',
        '새별오름', '새별프렌즈', '샤인빌파크CC', '서귀포치유의숲'
    ],
    "address": [""] * 10,  # Addresses are left empty as requested
    "description": [""] * 10,
    "link": [
        "https://www.visitjeju.net/kr/detail/view?contentsid=CONT_000000000500497", "http://www.blackstonecc.com/", 
        "https://www.visitjeju.net/kr/detail/view?contentsid=CONT_000000000500497", "http://www.bunkerdelumieres.com/", 
        "https://www.visitjeju.net/kr/detail/view?contentsid=CONT_000000000500497", "https://www.visitjeju.net/kr/detail/view?contentsid=CONT_000000000500497",
        "https://www.visitjeju.net/kr/detail/view?contentsid=CONT_000000000500497", "", "http://www.shinevill.com/", 
        "https://www.visitjeju.net/kr/detail/view?contentsid=CONT_000000000500497"
    ],
    "photo": [""] * 10
}

# Convert this batch into a DataFrame and append to the combined DataFrame
df_next_batch_3 = pd.DataFrame(next_batch_data_3)
df_combined = pd.concat([df_combined, df_next_batch_3], ignore_index=True)

df_combined
# Out:
#     Unnamed: 0          place address description  \
# 0           21         9.81파크
# 1           22       강창학종합경기장
# 2           23       갤러리2중선농원
# 3           24        건강과성박물관
# 4           25          고흐의정원
# 5           26        교래자연휴양림
# 6           27        국립제주박물관
# 7           28        국제리더스클럽
# 8           29       그리스신화박물관
# 9           30          금능석물원
# 10          31         금능해수욕장
# 11          32          기당미술관
# 12          33         김녕미로공원
# 13          34         김녕요트투어
# 14          35         김녕해수욕장
# 15          36         김만덕기념관
# 16          37      김영갑갤러리두모악
# 17          38         남원큰엉해변
# 18          39     너븐숭이4.3기념관
# 19          40         노형근린공원
# 20          41     대정현역사자료전시관
# 21          42           더마파크
# 22          43        돌하르방미술관
# 23          44           라온GC
# 24          45            만장굴
# 25          46          메이즈랜드
# 26          47         무민랜드제주
# 27          48  바이나흐튼크리스마스박물관
# 28          49            방림원
# ...

# %%
# Prepare the next batch of 10 locations and their details for the DataFrame
next_batch_data_4 = {
    "Unnamed: 0": range(61, 71),
    "place": [
        '서복전시관', '서프라이즈테마파크', '선녀와나무꾼테마공원', '섭지코지', '성산일출봉', '세계술박물관',
        '세리월드', '소암기념관', '소인국테마파크', '수목원테마파크아이스뮤지엄'
    ],
    "address": [""] * 10,  # Addresses are left empty as requested
    "description": [""] * 10,
    "link": [
        "https://www.visitjeju.net/kr/detail/view?contentsid=CONT_000000000500497", "", 
        "http://www.jejuattraction.co.kr/", "https://www.visitjeju.net/kr/detail/view?contentsid=CONT_000000000500497",
        "https://www.visitjeju.net/kr/detail/view?contentsid=CONT_000000000500497", "http://www.alcoholmuseum.co.kr/", 
        "http://www.seogwipo.go.kr/", "http://www.sogwipo.go.kr/museum/", "http://www.soingook.com/", ""
    ],
    "photo": [""] * 10
}

# Convert this batch into a DataFrame and append to the combined DataFrame
df_next_batch_4 = pd.DataFrame(next_batch_data_4)
df_combined = pd.concat([df_combined, df_next_batch_4], ignore_index=True)

df_combined
# Out:
#     Unnamed: 0          place address description  \
# 0           21         9.81파크
# 1           22       강창학종합경기장
# 2           23       갤러리2중선농원
# 3           24        건강과성박물관
# 4           25          고흐의정원
# 5           26        교래자연휴양림
# 6           27        국립제주박물관
# 7           28        국제리더스클럽
# 8           29       그리스신화박물관
# 9           30          금능석물원
# 10          31         금능해수욕장
# 11          32          기당미술관
# 12          33         김녕미로공원
# 13          34         김녕요트투어
# 14          35         김녕해수욕장
# 15          36         김만덕기념관
# 16          37      김영갑갤러리두모악
# 17          38         남원큰엉해변
# 18          39     너븐숭이4.3기념관
# 19          40         노형근린공원
# 20          41     대정현역사자료전시관
# 21          42           더마파크
# 22          43        돌하르방미술관
# 23          44           라온GC
# 24          45            만장굴
# 25          46          메이즈랜드
# 26          47         무민랜드제주
# 27          48  바이나흐튼크리스마스박물관
# 28          49            방림원
# ...

# %%
# Prepare the next batch of 10 locations and their details for the DataFrame
next_batch_data_5 = {
    "Unnamed: 0": range(71, 81),
    "place": [
        '숨도', '스카이워터쇼', '신양섭지해수욕장', '신창풍차해안도로', '아라리오뮤지엄동문모텔2', 
        '아프리카박물관', '애월해안도로', '에코랜드테마파크', '여미지식물원', '오설록티뮤지엄'
    ],
    "address": [""] * 10,  # Addresses are left empty as requested
    "description": [""] * 10,
    "link": [
        "https://www.sumdo.kr/", "", "https://www.visitjeju.net/kr/detail/view?contentsid=CONT_000000000500497", 
        "https://www.visitjeju.net/kr/detail/view?contentsid=CONT_000000000500497", "http://www.arariomuseum.org/",
        "http://www.africamuseum.co.kr/", "https://www.visitjeju.net/kr/detail/view?contentsid=CONT_000000000500497",
        "http://www.ecolandjeju.co.kr/", "http://www.yeomiji.co.kr/", "http://www.osulloc.com/"
    ],
    "photo": [""] * 10
}

# Convert this batch into a DataFrame and append to the combined DataFrame
df_next_batch_5 = pd.DataFrame(next_batch_data_5)
df_combined = pd.concat([df_combined, df_next_batch_5], ignore_index=True)

df_combined
# Out:
#     Unnamed: 0          place address description  \
# 0           21         9.81파크
# 1           22       강창학종합경기장
# 2           23       갤러리2중선농원
# 3           24        건강과성박물관
# 4           25          고흐의정원
# 5           26        교래자연휴양림
# 6           27        국립제주박물관
# 7           28        국제리더스클럽
# 8           29       그리스신화박물관
# 9           30          금능석물원
# 10          31         금능해수욕장
# 11          32          기당미술관
# 12          33         김녕미로공원
# 13          34         김녕요트투어
# 14          35         김녕해수욕장
# 15          36         김만덕기념관
# 16          37      김영갑갤러리두모악
# 17          38         남원큰엉해변
# 18          39     너븐숭이4.3기념관
# 19          40         노형근린공원
# 20          41     대정현역사자료전시관
# 21          42           더마파크
# 22          43        돌하르방미술관
# 23          44           라온GC
# 24          45            만장굴
# 25          46          메이즈랜드
# 26          47         무민랜드제주
# 27          48  바이나흐튼크리스마스박물관
# 28          49            방림원
# ...

# %%
# Prepare the next batch of 10 locations and their details for the DataFrame
next_batch_data_6 = {
    "Unnamed: 0": range(81, 91),
    "place": [
        '우도봉', '웅지승마센터', '윈드1947카트테마파크', '이중섭미술관', '일출랜드', '절물자연휴양림',
        '제주4.3평화공원', '제주곶자왈도립공원', '제주국제평화센터', '제주도립김창열미술관'
    ],
    "address": [""] * 10,  # Addresses are left empty as requested
    "description": [""] * 10,
    "link": [
        "https://www.visitjeju.net/kr/detail/view?contentsid=CONT_000000000500497", 
        "http://www.woongjeh.co.kr/", "http://www.wind1947.com/", "http://www.seogwipo.go.kr/jsmuseum/",
        "http://www.ilchul.com/", "https://www.visitjeju.net/kr/detail/view?contentsid=CONT_000000000500497",
        "http://www.jeju43peacepark.or.kr/", "http://www.gotjawal.kr/", "https://www.jipc.or.kr/", 
        "http://kimchangmuseum.jeju.go.kr/"
    ],
    "photo": [""] * 10
}

# Convert this batch into a DataFrame and append to the combined DataFrame
df_next_batch_6 = pd.DataFrame(next_batch_data_6)
df_combined = pd.concat([df_combined, df_next_batch_6], ignore_index=True)

df_combined
# Out:
#     Unnamed: 0       place address description  \
# 0           21      9.81파크
# 1           22    강창학종합경기장
# 2           23    갤러리2중선농원
# 3           24     건강과성박물관
# 4           25       고흐의정원
# ..         ...         ...     ...         ...
# 65          86     절물자연휴양림
# 66          87   제주4.3평화공원
# 67          88   제주곶자왈도립공원
# 68          89    제주국제평화센터
# 69          90  제주도립김창열미술관
#
#                                                  link photo
# 0                            https://www.981park.com/
# 1
# 2
# 3                         http://www.sexmuseum.or.kr/
# 4                      https://goghs-garden.modoo.at/
# ..                                                ...   ...
# 65  https://www.visitjeju.net/kr/detail/view?conte...
# 66                  http://www.jeju43peacepark.or.kr/
# 67                            http://www.gotjawal.kr/
# 68                            https://www.jipc.or.kr/
# 69                  http://kimchangmuseum.jeju.go.kr/
#
# [70 rows x 6 columns]

# %%
# Prepare the final batch of 10 locations and their details for the DataFrame
final_batch_data = {
    "Unnamed: 0": range(91, 101),
    "place": [
        '제주도립미술관', '제주돌문화공원', '제주러브랜드', '제주민속촌', '제주불빛정원', '제주시민속오일시장',
        '제주신화월드', '제주아트서커스', '제주영상문화산업진흥원', '제주월드컵경기장'
    ],
    "address": [""] * 10,  # Addresses are left empty as requested
    "description": [""] * 10,
    "link": [
        "https://artmuseum.jeju.go.kr/", "http://www.jejudollpark.com/", "http://www.jejuloveland.com/", 
        "http://www.jejuminsok.co.kr/", "http://www.jejudreamforest.kr/", 
        "https://www.visitjeju.net/kr/detail/view?contentsid=CONT_000000000500497", "https://www.shinhwaworld.com/",
        "http://www.jejuartcircus.com/", "http://www.jima.or.kr/", 
        "https://www.visitjeju.net/kr/detail/view?contentsid=CONT_000000000500497"
    ],
    "photo": [""] * 10
}

# Convert this batch into a DataFrame and append to the combined DataFrame
df_final_batch = pd.DataFrame(final_batch_data)
df_combined = pd.concat([df_combined, df_final_batch], ignore_index=True)

df_combined
# Out:
#     Unnamed: 0        place address description  \
# 0           21       9.81파크
# 1           22     강창학종합경기장
# 2           23     갤러리2중선농원
# 3           24      건강과성박물관
# 4           25        고흐의정원
# ..         ...          ...     ...         ...
# 75          96    제주시민속오일시장
# 76          97       제주신화월드
# 77          98      제주아트서커스
# 78          99  제주영상문화산업진흥원
# 79         100     제주월드컵경기장
#
#                                                  link photo
# 0                            https://www.981park.com/
# 1
# 2
# 3                         http://www.sexmuseum.or.kr/
# 4                      https://goghs-garden.modoo.at/
# ..                                                ...   ...
# 75  https://www.visitjeju.net/kr/detail/view?conte...
# 76                      https://www.shinhwaworld.com/
# 77                      http://www.jejuartcircus.com/
# 78                             http://www.jima.or.kr/
# 79  https://www.visitjeju.net/kr/detail/view?conte...
#
# ...

# %%
# Prepare the final batch to complete the remaining 8 locations for the DataFrame
final_batch_data_2 = {
    "Unnamed: 0": range(101, 109),
    "place": [
        '제주종합경기장', '제주차귀도요트투어', '제주커피박물관바움', '제주코코몽에코파크', '제주학생문화원',
        '제주항공우주박물관', '제주항일기념관', '제주해양동물박물관'
    ],
    "address": [""] * 8,  # Addresses are left empty as requested
    "description": [""] * 8,
    "link": [
        "https://www.visitjeju.net/kr/detail/view?contentsid=CONT_000000000500497", 
        "http://www.jeju4skyyachttour.com/", "http://www.coffeebaum.co.kr/", 
        "http://www.cocomongecopark.com/", "https://edu.jeju.go.kr/edu/main/main.do", 
        "http://www.jdc-jam.com/", "https://www.visitjeju.net/kr/detail/view?contentsid=CONT_000000000500497", 
        "http://www.jejumuseum.co.kr/"
    ],
    "photo": [""] * 8
}

# Convert this final batch into a DataFrame and append to the combined DataFrame
df_final_batch_2 = pd.DataFrame(final_batch_data_2)
df_combined = pd.concat([df_combined, df_final_batch_2], ignore_index=True)

df_combined
# Out:
#     Unnamed: 0      place address description  \
# 0           21     9.81파크
# 1           22   강창학종합경기장
# 2           23   갤러리2중선농원
# 3           24    건강과성박물관
# 4           25      고흐의정원
# ..         ...        ...     ...         ...
# 83         104  제주코코몽에코파크
# 84         105    제주학생문화원
# 85         106  제주항공우주박물관
# 86         107    제주항일기념관
# 87         108  제주해양동물박물관
#
#                                                  link photo
# 0                            https://www.981park.com/
# 1
# 2
# 3                         http://www.sexmuseum.or.kr/
# 4                      https://goghs-garden.modoo.at/
# ..                                                ...   ...
# 83                    http://www.cocomongecopark.com/
# 84            https://edu.jeju.go.kr/edu/main/main.do
# 85                            http://www.jdc-jam.com/
# 86  https://www.visitjeju.net/kr/detail/view?conte...
# 87                       http://www.jejumuseum.co.kr/
#
# [88 rows x 6 columns]

# %%
# Combine all the previously created DataFrames in one go to ensure a single, unified DataFrame
# This is an assumption based on the provided information

# Consolidate all data into one DataFrame
full_data = {
    "Unnamed: 0": list(range(21, 21 + len(df_combined))),  # Ensuring sequential numbering
    "place": df_combined['place'],
    "address": df_combined['address'],
    "description": df_combined['description'],
    "link": df_combined['link'],
    "photo": df_combined['photo']
}

# Create the full DataFrame
df_full_combined = pd.DataFrame(full_data)

# Display the final DataFrame
df_full_combined
# Out:
#     Unnamed: 0      place address description  \
# 0           21     9.81파크
# 1           22   강창학종합경기장
# 2           23   갤러리2중선농원
# 3           24    건강과성박물관
# 4           25      고흐의정원
# ..         ...        ...     ...         ...
# 83         104  제주코코몽에코파크
# 84         105    제주학생문화원
# 85         106  제주항공우주박물관
# 86         107    제주항일기념관
# 87         108  제주해양동물박물관
#
#                                                  link photo
# 0                            https://www.981park.com/
# 1
# 2
# 3                         http://www.sexmuseum.or.kr/
# 4                      https://goghs-garden.modoo.at/
# ..                                                ...   ...
# 83                    http://www.cocomongecopark.com/
# 84            https://edu.jeju.go.kr/edu/main/main.do
# 85                            http://www.jdc-jam.com/
# 86  https://www.visitjeju.net/kr/detail/view?conte...
# 87                       http://www.jejumuseum.co.kr/
#
# [88 rows x 6 columns]

# %%
df3 = df_full_combined
df3['place'].unique
# Out:
# <bound method Series.unique of 0        9.81파크
# 1      강창학종합경기장
# 2      갤러리2중선농원
# 3       건강과성박물관
# 4         고흐의정원
#         ...
# 83    제주코코몽에코파크
# 84      제주학생문화원
# 85    제주항공우주박물관
# 86      제주항일기념관
# 87    제주해양동물박물관
# Name: place, Length: 88, dtype: object>

# %%
df3
# Out:
#     Unnamed: 0      place address description  \
# 0           21     9.81파크
# 1           22   강창학종합경기장
# 2           23   갤러리2중선농원
# 3           24    건강과성박물관
# 4           25      고흐의정원
# ..         ...        ...     ...         ...
# 83         104  제주코코몽에코파크
# 84         105    제주학생문화원
# 85         106  제주항공우주박물관
# 86         107    제주항일기념관
# 87         108  제주해양동물박물관
#
#                                                  link photo
# 0                            https://www.981park.com/
# 1
# 2
# 3                         http://www.sexmuseum.or.kr/
# 4                      https://goghs-garden.modoo.at/
# ..                                                ...   ...
# 83                    http://www.cocomongecopark.com/
# 84            https://edu.jeju.go.kr/edu/main/main.do
# 85                            http://www.jdc-jam.com/
# 86  https://www.visitjeju.net/kr/detail/view?conte...
# 87                       http://www.jejumuseum.co.kr/
#
# [88 rows x 6 columns]

# %%
# 'place' 컬럼을 기준으로 중복된 값을 제거하며 df와 df3을 위아래로 합치는 코드
# 먼저 df3에서 df에 있는 place 값을 제거한 후 합칩니다

# 1. df3에서 df와 중복되지 않는 'place' 값만 필터링
df3_filtered = df3[~df3['place'].isin(df2['place'])]

# 2. 위아래로 합치기 (중복된 'place'가 없는 df3_filtered를 추가)
df_combined = pd.concat([df2, df3_filtered], ignore_index=True)

# 결과 확인
df_combined
# Out:
#     Unnamed: 0      place                     address  \
# 0            0     김녕해수욕장         제주특별자치도 제주시 구좌읍 김녕리
# 1            1   에코랜드테마파크    제주특별자치도 제주시 조천읍 남조로 2020
# 2            2      카멜리아힐  제주특별자치도 서귀포시 안덕면 상창리 557-3
# 3            3       섭지코지      제주특별자치도 서귀포시 성산읍 섭지코지로
# 4            4    절물자연휴양림     제주특별자치도 제주시 한경면 절물로 168
# ..         ...        ...                         ...
# 88         103  제주커피박물관바움
# 89         104  제주코코몽에코파크
# 90         105    제주학생문화원
# 91         107    제주항일기념관
# 92         108  제주해양동물박물관
#
#                        description  \
# 0   에메랄드빛 바다가 펼쳐진 제주 동부의 아름다운 해수욕장
# 1     제주 숲 속 기차여행을 즐길 수 있는 자연 테마파크
# 2            수많은 동백꽃이 아름답게 피어나는 정원
# 3        제주의 동쪽 해안 절경을 감상할 수 있는 명소
# 4         숲 속에서의 힐링을 즐길 수 있는 자연휴양림
# ..                             ...
# 88
# 89
# 90
# 91
# 92
#
#                                                  link          photo
# 0   https://www.visitjeju.net/kr/detail/view?conte...  data_1/01.jpg
# ...

# %%
import pandas as pd
df_combined.to_csv('placeinfo.csv', index=False, encoding='utf-8-sig')

# %%
# Adding descriptions in manageable groups
# I'll create a dictionary with example descriptions for each missing place

# First batch of 20 descriptions
descriptions_batch_1 = {
    '강창학종합경기장': '다양한 스포츠와 문화 행사가 열리는 종합경기장입니다.',
    '갤러리2중선농원': '자연과 예술이 어우러진 갤러리와 농원이 있는 곳입니다.',
    '건강과성박물관': '건강과 성에 대한 다양한 전시와 교육 프로그램이 있는 박물관입니다.',
    '고흐의정원': '고흐의 작품을 모티브로 한 아름다운 정원입니다.',
    '교래자연휴양림': '제주 자연 속에서 휴식을 취할 수 있는 휴양림입니다.',
    '국제리더스클럽': '세계적인 리더들이 모이는 모임 공간과 교육 시설입니다.',
    '금능석물원': '전통적인 석물 조각이 전시된 정원입니다.',
    '금능해수욕장': '제주의 맑고 푸른 바다를 즐길 수 있는 해수욕장입니다.',
    '기당미술관': '현대미술 전시를 중심으로 한 제주 지역의 미술관입니다.',
    '김녕미로공원': '다양한 테마의 미로를 즐길 수 있는 공원입니다.',
    '김녕요트투어': '제주의 해안을 따라 요트를 타고 즐길 수 있는 투어입니다.',
    '김영갑갤러리두모악': '사진작가 김영갑의 작품이 전시된 갤러리입니다.',
    '노형근린공원': '산책로와 녹지가 잘 조성된 도심 속 공원입니다.',
    '대정현역사자료전시관': '대정 지역의 역사와 문화를 알 수 있는 전시관입니다.',
    '돌하르방미술관': '제주도의 상징인 돌하르방을 테마로 한 미술관입니다.',
    '라온GC': '제주의 아름다운 자연과 함께하는 골프 클럽입니다.',
    '만장굴': '천연 용암 동굴로 아름다운 지형을 자랑합니다.',
    '메이즈랜드': '미로를 테마로 한 다양한 놀이와 체험이 있는 테마파크입니다.',
    '무민랜드제주': '무민 캐릭터를 테마로 한 아기자기한 테마파크입니다.',
    '바이나흐튼크리스마스박물관': '크리스마스를 테마로 한 다양한 전시가 열리는 박물관입니다.'
}

# Apply the first batch of descriptions to the DataFrame
df_combined.loc[df_combined['place'].isin(descriptions_batch_1.keys()), 'description'] = \
    df_combined['place'].map(descriptions_batch_1)

# Display the updated DataFrame to verify the first batch
df_combined[df_combined['place'].isin(descriptions_batch_1.keys())]
# Out:
#     Unnamed: 0          place address                            description  \
# 20          22       강창학종합경기장                  다양한 스포츠와 문화 행사가 열리는 종합경기장입니다.
# 21          23       갤러리2중선농원                 자연과 예술이 어우러진 갤러리와 농원이 있는 곳입니다.
# 22          24        건강과성박물관          건강과 성에 대한 다양한 전시와 교육 프로그램이 있는 박물관입니다.
# 23          25          고흐의정원                     고흐의 작품을 모티브로 한 아름다운 정원입니다.
# 24          26        교래자연휴양림                  제주 자연 속에서 휴식을 취할 수 있는 휴양림입니다.
# 25          28        국제리더스클럽                 세계적인 리더들이 모이는 모임 공간과 교육 시설입니다.
# 26          30          금능석물원                         전통적인 석물 조각이 전시된 정원입니다.
# 27          31         금능해수욕장                 제주의 맑고 푸른 바다를 즐길 수 있는 해수욕장입니다.
# 28          32          기당미술관                 현대미술 전시를 중심으로 한 제주 지역의 미술관입니다.
# 29          33         김녕미로공원                     다양한 테마의 미로를 즐길 수 있는 공원입니다.
# 30          34         김녕요트투어               제주의 해안을 따라 요트를 타고 즐길 수 있는 투어입니다.
# ...

# %%
# Second batch of 20 descriptions for the next set of places

descriptions_batch_2 = {
    '방림원': '제주도 전통 식물과 꽃들을 감상할 수 있는 자연 정원입니다.',
    '본태박물관': '제주 전통과 현대 예술이 공존하는 예술 박물관입니다.',
    '붉은오름자연휴양림': '붉은오름 숲 속에서 산책과 힐링을 즐길 수 있는 자연 휴양림입니다.',
    '블랙스톤제주CC': '멋진 경관을 자랑하는 고급 골프 클럽입니다.',
    '비자림': '비자나무 숲이 펼쳐진 제주도의 유명한 자연 관광지입니다.',
    '빛의벙커': '화려한 빛과 예술이 결합된 미디어 아트 전시 공간입니다.',
    '사계해안': '아름다운 바다와 해안 절경을 감상할 수 있는 제주도의 해안입니다.',
    '사라봉공원': '도심에서 자연을 즐길 수 있는 녹지 공원입니다.',
    '새별오름': '제주도의 자연 경관을 즐길 수 있는 오름 중 하나입니다.',
    '새별프렌즈': '가족과 함께 즐길 수 있는 다양한 체험이 있는 공간입니다.',
    '샤인빌파크CC': '청정한 자연 속에서 즐기는 골프 클럽입니다.',
    '서귀포치유의숲': '자연 속에서 치유와 힐링을 제공하는 숲 체험 장소입니다.',
    '서복전시관': '중국 진시황의 불사의 약을 찾으러 떠난 서복을 기리는 전시관입니다.',
    '서프라이즈테마파크': '아이들과 가족들이 함께 즐길 수 있는 테마파크입니다.',
    '섭지코지': '드넓은 바다와 초원이 펼쳐진 제주도의 명소입니다.',
    '성산일출봉': '제주의 해돋이 명소로, UNESCO 세계 자연유산에 등재된 명소입니다.',
    '세계술박물관': '세계 각국의 다양한 술을 전시하는 박물관입니다.',
    '세리월드': '다양한 체험 프로그램이 있는 가족 놀이 공간입니다.',
    '소암기념관': '제주 출신의 서예가 소암의 작품을 기리는 기념관입니다.',
    '소인국테마파크': '세계의 랜드마크들을 미니어처로 재현한 테마파크입니다.'
}

# Apply the second batch of descriptions to the DataFrame
df_combined.loc[df_combined['place'].isin(descriptions_batch_2.keys()), 'description'] = \
    df_combined['place'].map(descriptions_batch_2)

# Display the updated DataFrame to verify the second batch
df_combined[df_combined['place'].isin(descriptions_batch_2.keys())]
# Out:
#     Unnamed: 0      place                  address  \
# 3            3       섭지코지   제주특별자치도 서귀포시 성산읍 섭지코지로
# 8            8  서프라이즈테마파크  제주특별자치도 제주시 한림읍 한림로 220
# 40          49        방림원
# 41          50      본태박물관
# 42          51  붉은오름자연휴양림
# 43          52   블랙스톤제주CC
# 44          53        비자림
# 45          54       빛의벙커
# 46          55       사계해안
# 47          56      사라봉공원
# 48          57       새별오름
# 49          58      새별프렌즈
# 50          59    샤인빌파크CC
# 51          60    서귀포치유의숲
# 52          61      서복전시관
# 53          65      성산일출봉
# 54          66     세계술박물관
# 55          67       세리월드
# 56          68      소암기념관
# 57          69    소인국테마파크
#
#                                 description  \
# 3               드넓은 바다와 초원이 펼쳐진 제주도의 명소입니다.
# 8             아이들과 가족들이 함께 즐길 수 있는 테마파크입니다.
# 40        제주도 전통 식물과 꽃들을 감상할 수 있는 자연 정원입니다.
# 41            제주 전통과 현대 예술이 공존하는 예술 박물관입니다.
# 42    붉은오름 숲 속에서 산책과 힐링을 즐길 수 있는 자연 휴양림입니다.
# 43                 멋진 경관을 자랑하는 고급 골프 클럽입니다.
# ...

# %%
# Third batch of 20 descriptions for the next set of places

descriptions_batch_3 = {
    '수목원테마파크아이스뮤지엄': '제주의 수목원과 함께 아이스 테마가 결합된 독특한 박물관입니다.',
    '숨도': '평화로운 자연 속에서 편안한 시간을 보낼 수 있는 힐링 장소입니다.',
    '스카이워터쇼': '제주의 바다와 하늘을 배경으로 펼쳐지는 환상적인 워터쇼입니다.',
    '신양섭지해수욕장': '섭지코지 근처에 위치한 아름다운 해수욕장입니다.',
    '신창풍차해안도로': '풍차가 있는 해안도로로, 멋진 풍경을 자랑합니다.',
    '아라리오뮤지엄동문모텔2': '독특한 미술 작품이 전시된 제주 동문 지역의 모던한 미술관입니다.',
    '아프리카박물관': '아프리카의 다양한 문화를 소개하는 이국적인 박물관입니다.',
    '애월해안도로': '드라이브 코스로 유명한 해안도로로, 제주 바다를 가까이서 즐길 수 있습니다.',
    '에코랜드테마파크': '제주의 숲 속에서 기차를 타고 자연을 탐방할 수 있는 테마파크입니다.',
    '여미지식물원': '다양한 식물과 함께하는 테마 식물원으로, 아름다운 정원이 있습니다.',
    '오설록티뮤지엄': '제주의 대표적인 차 박물관으로, 다양한 차 문화 체험이 가능합니다.',
    '우도봉': '우도의 상징적인 봉우리로, 제주 바다와 우도를 한눈에 감상할 수 있습니다.',
    '웅지승마센터': '제주에서 말을 타고 체험할 수 있는 승마센터입니다.',
    '윈드1947카트테마파크': '스릴 넘치는 카트 체험을 즐길 수 있는 테마파크입니다.',
    '이중섭미술관': '제주에서 활동한 화가 이중섭을 기리는 미술관입니다.',
    '일출랜드': '제주의 자연을 주제로 한 테마파크로, 다양한 식물과 조각품이 있습니다.',
    '제주4.3평화공원': '제주 4.3 사건을 기념하는 평화공원입니다.',
    '제주곶자왈도립공원': '제주에서 독특한 생태계를 보존하는 곶자왈 숲입니다.',
    '제주국제평화센터': '제주에서 열리는 국제 평화 회의 및 행사들이 열리는 장소입니다.',
    '제주도립김창열미술관': '현대미술 작가 김창열의 작품을 기리는 미술관입니다.'
}

# Apply the third batch of descriptions to the DataFrame
df_combined.loc[df_combined['place'].isin(descriptions_batch_3.keys()), 'description'] = \
    df_combined['place'].map(descriptions_batch_3)

# Display the updated DataFrame to verify the third batch
df_combined[df_combined['place'].isin(descriptions_batch_3.keys())]
# Out:
#     Unnamed: 0          place                   address  \
# 1            1       에코랜드테마파크  제주특별자치도 제주시 조천읍 남조로 2020
# 58          70  수목원테마파크아이스뮤지엄
# 59          71             숨도
# 60          72         스카이워터쇼
# 61          73       신양섭지해수욕장
# 62          74       신창풍차해안도로
# 63          75   아라리오뮤지엄동문모텔2
# 64          76        아프리카박물관
# 65          77         애월해안도로
# 66          79         여미지식물원
# 67          80        오설록티뮤지엄
# 68          81            우도봉
# 69          82         웅지승마센터
# 70          83   윈드1947카트테마파크
# 71          84         이중섭미술관
# 72          85           일출랜드
# 73          87      제주4.3평화공원
# 74          88      제주곶자왈도립공원
# 75          89       제주국제평화센터
# 76          90     제주도립김창열미술관
#
#                                    description  \
# 1       제주의 숲 속에서 기차를 타고 자연을 탐방할 수 있는 테마파크입니다.
# 58         제주의 수목원과 함께 아이스 테마가 결합된 독특한 박물관입니다.
# 59       평화로운 자연 속에서 편안한 시간을 보낼 수 있는 힐링 장소입니다.
# 60          제주의 바다와 하늘을 배경으로 펼쳐지는 환상적인 워터쇼입니다.
# ...

# %%
# Fourth batch of descriptions for the remaining 13 places

descriptions_batch_4 = {
    '제주도립미술관': '제주의 대표적인 미술관으로, 현대 미술 작품들을 전시합니다.',
    '제주돌문화공원': '제주 전통의 돌 문화를 테마로 한 공원입니다.',
    '제주러브랜드': '성인 테마의 조각 공원이자 예술 공간입니다.',
    '제주민속촌': '제주의 전통 민속 문화를 경험할 수 있는 민속촌입니다.',
    '제주불빛정원': '아름다운 불빛이 조화를 이루는 정원입니다.',
    '제주시민속오일시장': '제주의 다양한 농산물과 특산품을 만날 수 있는 전통 시장입니다.',
    '제주신화월드': '여러 테마로 이루어진 대규모 복합 리조트입니다.',
    '제주아트서커스': '화려한 공연이 펼쳐지는 제주도의 서커스 공연장입니다.',
    '제주영상문화산업진흥원': '영상과 문화 산업을 지원하는 제주도의 문화 공간입니다.',
    '제주월드컵경기장': '월드컵 경기를 위해 지어진 종합 스포츠 경기장입니다.',
    '제주종합경기장': '다양한 스포츠 경기가 열리는 종합 경기장입니다.',
    '제주차귀도요트투어': '제주 바다에서 요트 투어를 즐길 수 있는 해상 체험입니다.',
    '제주커피박물관바움': '커피의 역사와 문화를 소개하는 박물관입니다.'
}

# Apply the fourth batch of descriptions to the DataFrame
df_combined.loc[df_combined['place'].isin(descriptions_batch_4.keys()), 'description'] = \
    df_combined['place'].map(descriptions_batch_4)

# Display the updated DataFrame to verify all descriptions are added
df_combined[df_combined['place'].isin(descriptions_batch_4.keys())]
# Out:
#     Unnamed: 0        place            address  \
# 15          15      제주도립미술관  제주특별자치도 제주시 연동 65
# 77          92      제주돌문화공원
# 78          93       제주러브랜드
# 79          94        제주민속촌
# 80          95       제주불빛정원
# 81          96    제주시민속오일시장
# 82          97       제주신화월드
# 83          98      제주아트서커스
# 84          99  제주영상문화산업진흥원
# 85         100     제주월드컵경기장
# 86         101      제주종합경기장
# 87         102    제주차귀도요트투어
# 88         103    제주커피박물관바움
#
#                             description  \
# 15    제주의 대표적인 미술관으로, 현대 미술 작품들을 전시합니다.
# 77            제주 전통의 돌 문화를 테마로 한 공원입니다.
# 78             성인 테마의 조각 공원이자 예술 공간입니다.
# 79       제주의 전통 민속 문화를 경험할 수 있는 민속촌입니다.
# 80              아름다운 불빛이 조화를 이루는 정원입니다.
# 81  제주의 다양한 농산물과 특산품을 만날 수 있는 전통 시장입니다.
# 82           여러 테마로 이루어진 대규모 복합 리조트입니다.
# 83        화려한 공연이 펼쳐지는 제주도의 서커스 공연장입니다.
# 84       영상과 문화 산업을 지원하는 제주도의 문화 공간입니다.
# 85        월드컵 경기를 위해 지어진 종합 스포츠 경기장입니다.
# 86           다양한 스포츠 경기가 열리는 종합 경기장입니다.
# ...

# %%
# Applying the description batches to `df_combined`'s 'description' column

# Define all batches together as a single dictionary for convenience
all_descriptions = {
    **descriptions_batch_1, 
    **descriptions_batch_2, 
    **descriptions_batch_3, 
    **descriptions_batch_4
}

# Apply these descriptions to `df_combined`
df_combined.loc[df_combined['place'].isin(all_descriptions.keys()), 'description'] = \
    df_combined['place'].map(all_descriptions)

# Display the updated `df_combined` to verify descriptions were added correctly
df_combined[df_combined['place'].isin(all_descriptions.keys())]
# Out:
#     Unnamed: 0        place                   address  \
# 1            1     에코랜드테마파크  제주특별자치도 제주시 조천읍 남조로 2020
# 3            3         섭지코지    제주특별자치도 서귀포시 성산읍 섭지코지로
# 8            8    서프라이즈테마파크   제주특별자치도 제주시 한림읍 한림로 220
# 15          15      제주도립미술관         제주특별자치도 제주시 연동 65
# 20          22     강창학종합경기장
# ..         ...          ...                       ...
# 84          99  제주영상문화산업진흥원
# 85         100     제주월드컵경기장
# 86         101      제주종합경기장
# 87         102    제주차귀도요트투어
# 88         103    제주커피박물관바움
#
#                                description  \
# 1   제주의 숲 속에서 기차를 타고 자연을 탐방할 수 있는 테마파크입니다.
# 3              드넓은 바다와 초원이 펼쳐진 제주도의 명소입니다.
# 8            아이들과 가족들이 함께 즐길 수 있는 테마파크입니다.
# 15       제주의 대표적인 미술관으로, 현대 미술 작품들을 전시합니다.
# 20           다양한 스포츠와 문화 행사가 열리는 종합경기장입니다.
# ..                                     ...
# 84          영상과 문화 산업을 지원하는 제주도의 문화 공간입니다.
# 85           월드컵 경기를 위해 지어진 종합 스포츠 경기장입니다.
# 86              다양한 스포츠 경기가 열리는 종합 경기장입니다.
# ...

# %%
df_combined['place'].unique
# Out:
# <bound method Series.unique of 0        김녕해수욕장
# 1      에코랜드테마파크
# 2         카멜리아힐
# 3          섭지코지
# 4       절물자연휴양림
#         ...
# 88    제주커피박물관바움
# 89    제주코코몽에코파크
# 90      제주학생문화원
# 91      제주항일기념관
# 92    제주해양동물박물관
# Name: place, Length: 93, dtype: object>

# %%
unique_values = df['FCLTY_NM'].unique()

# 전체 값을 보기 위해 리스트로 변환하여 출력
print(list(unique_values))
# Out:
# ['9.81파크', '강창학종합경기장', '갤러리2중선농원', '건강과성박물관', '고흐의정원', '교래자연휴양림', '국립제주박물관', '국제리더스클럽', '그리스신화박물관', '금능석물원', '금능해수욕장', '기당미술관', '김녕미로공원', '김녕요트투어', '김녕해수욕장', '김만덕기념관', '김영갑갤러리두모악', '남원큰엉해변', '너븐숭이4.3기념관', '노형근린공원', '대정현역사자료전시관', '더마파크', '돌하르방미술관', '라온GC', '만장굴', '메이즈랜드', '무민랜드제주', '바이나흐튼크리스마스박물관', '방림원', '본태박물관', '붉은오름자연휴양림', '블랙스톤제주CC', '비자림', '빛의벙커', '사계해안', '사라봉공원', '새별오름', '새별프렌즈', '샤인빌파크CC', '서귀포치유의숲', '서복전시관', '서프라이즈테마파크', '선녀와나무꾼테마공원', '섭지코지', '성산일출봉', '세계술박물관', '세리월드', '소암기념관', '소인국테마파크', '수목원테마파크아이스뮤지엄', '숨도', '스카이워터쇼', '신양섭지해수욕장', '신창풍차해안도로', '아라리오뮤지엄동문모텔2', '아프리카박물관', '애월해안도로', '에코랜드테마파크', '여미지식물원', '오설록티뮤지엄', '우도봉', '웅지승마센터', '윈드1947카트테마파크', '이중섭미술관', '일출랜드', '절물자연휴양림', '제주4.3평화공원', '제주4.3평화공원제주4.3평화기념관', '제주곶자왈도립공원', '제주국제평화센터', '제주도립김창열미술관', '제주도립미술관', '제주돌문화공원', '제주러브랜드', '제주민속촌', '제주불빛정원', '제주시민속오일시장', '제주신화월드', '제주아트서커스', '제주영상문화산업진흥원', '제주월드컵경기장', '제주종합경기장', '제주차귀도요트투어', '제주커피박물관바움', '제주코코몽에코파크', '제주학생문화원', '제주항공우주박물관', '제주항일기념관', '제주해양동물박물관', '제주현대미술관', '조안베어뮤지엄', 
# ...

# %%
df_combined
# Out:
#     Unnamed: 0      place                     address  \
# 0            0     김녕해수욕장         제주특별자치도 제주시 구좌읍 김녕리
# 1            1   에코랜드테마파크    제주특별자치도 제주시 조천읍 남조로 2020
# 2            2      카멜리아힐  제주특별자치도 서귀포시 안덕면 상창리 557-3
# 3            3       섭지코지      제주특별자치도 서귀포시 성산읍 섭지코지로
# 4            4    절물자연휴양림     제주특별자치도 제주시 한경면 절물로 168
# ..         ...        ...                         ...
# 88         103  제주커피박물관바움
# 89         104  제주코코몽에코파크
# 90         105    제주학생문화원
# 91         107    제주항일기념관
# 92         108  제주해양동물박물관
#
#                                description  \
# 0           에메랄드빛 바다가 펼쳐진 제주 동부의 아름다운 해수욕장
# 1   제주의 숲 속에서 기차를 타고 자연을 탐방할 수 있는 테마파크입니다.
# 2                    수많은 동백꽃이 아름답게 피어나는 정원
# 3              드넓은 바다와 초원이 펼쳐진 제주도의 명소입니다.
# 4                 숲 속에서의 힐링을 즐길 수 있는 자연휴양림
# ..                                     ...
# 88                커피의 역사와 문화를 소개하는 박물관입니다.
# 89
# 90
# 91
# 92
#
#                                                  link          photo
# ...

# %%
address_dict = {
    '9.81파크': '제주특별자치도 제주시 애월읍 천덕로 880-24',
    '강창학종합경기장': '제주특별자치도 서귀포시 월드컵로 33',
    '갤러리2중선농원': '제주특별자치도 제주시 애월읍 하가로 284',
    '건강과성박물관': '제주특별자치도 서귀포시 상예로 178-19',
    '고흐의정원': '제주특별자치도 서귀포시 안덕면 평화로 1100',
    '교래자연휴양림': '제주특별자치도 제주시 조천읍 남조로 2023',
    '국립제주박물관': '제주특별자치도 제주시 일주동로 17',
    '국제리더스클럽': '제주특별자치도 제주시 연동 292-30',
    '그리스신화박물관': '제주특별자치도 제주시 애월읍 평화로 990',
    '금능석물원': '제주특별자치도 제주시 한림읍 금능남로 128',
    '금능해수욕장': '제주특별자치도 제주시 한림읍 금능리 2036-1',
    '기당미술관': '제주특별자치도 서귀포시 남성중로 27',
    '김녕미로공원': '제주특별자치도 제주시 구좌읍 만장굴길 122',
    '김녕요트투어': '제주특별자치도 제주시 구좌읍 김녕리 522-12',
    '김녕해수욕장': '제주특별자치도 제주시 구좌읍 해맞이해안로 1012',
    '김만덕기념관': '제주특별자치도 제주시 산지로 7',
    '김영갑갤러리두모악': '제주특별자치도 서귀포시 성산읍 삼달로 137',
    '남원큰엉해변': '제주특별자치도 서귀포시 남원읍 큰엉해안로',
    '너븐숭이4.3기념관': '제주특별자치도 제주시 조천읍 북촌길 43',
    '노형근린공원': '제주특별자치도 제주시 노형동 3793-2',
    '대정현역사자료전시관': '제주특별자치도 서귀포시 대정읍 하모리 980-1',
    '더마파크': '제주특별자치도 제주시 한림읍 월림7길 155',
    '돌하르방미술관': '제주특별자치도 제주시 조천읍 남조로 2023',
    '라온GC': '제주특별자치도 제주시 한림읍 금악리 1213',
    '만장굴': '제주특별자치도 제주시 구좌읍 만장굴길 182',
    '메이즈랜드': '제주특별자치도 제주시 구좌읍 비자림로 2134-47',
    '무민랜드제주': '제주특별자치도 제주시 구좌읍 동복로 39-12',
    '바이나흐튼크리스마스박물관': '제주특별자치도 서귀포시 안덕면 평화로 654',
    '방림원': '제주특별자치도 서귀포시 안덕면 병악로 186',
    '본태박물관': '제주특별자치도 서귀포시 안덕면 산록남로762번길 69',
    '붉은오름자연휴양림': '제주특별자치도 서귀포시 표선면 남조로 1487-72',
    '블랙스톤제주CC': '제주특별자치도 제주시 한경면 녹차분재로 566-27',
    '비자림': '제주특별자치도 제주시 구좌읍 비자숲길 55',
    '빛의벙커': '제주특별자치도 서귀포시 성산읍 고성리 2039-22',
    '사계해안': '제주특별자치도 서귀포시 안덕면 사계리',
    '사라봉공원': '제주특별자치도 제주시 건입동 산 1-1',
    '새별오름': '제주특별자치도 제주시 애월읍 봉성리 산 59-8',
    '새별프렌즈': '제주특별자치도 제주시 애월읍 봉성리 1666-1',
    '샤인빌파크CC': '제주특별자치도 서귀포시 표선면 민속해안로 634',
    '서귀포치유의숲': '제주특별자치도 서귀포시 산록남로 2271-745',
    '서복전시관': '제주특별자치도 서귀포시 칠십리로 156',
    '서프라이즈테마파크': '제주특별자치도 제주시 애월읍 평화로 1529',
    '선녀와나무꾼테마공원': '제주특별자치도 제주시 조천읍 선교로 267',
    '섭지코지': '제주특별자치도 서귀포시 성산읍 섭지코지로 107',
    '성산일출봉': '제주특별자치도 서귀포시 성산읍 일출로 1',
    '세계술박물관': '제주특별자치도 제주시 애월읍 평화로 2171-21',
    '세리월드': '제주특별자치도 서귀포시 법환동 256-1',
    '소암기념관': '제주특별자치도 서귀포시 남성중로 27-3',
    '소인국테마파크': '제주특별자치도 서귀포시 안덕면 중산간서로 1878',
    '수목원테마파크아이스뮤지엄': '제주특별자치도 제주시 은수길 69',
    '숨도': '제주특별자치도 서귀포시 안덕면 화순리 2933',
    '스카이워터쇼': '제주특별자치도 서귀포시 중문관광로 72번길 29',
    '신양섭지해수욕장': '제주특별자치도 서귀포시 성산읍 섭지코지로 114',
    '신창풍차해안도로': '제주특별자치도 제주시 한경면 신창리',
    '아라리오뮤지엄동문모텔2': '제주특별자치도 제주시 중앙로 69',
    '아프리카박물관': '제주특별자치도 서귀포시 이어도로 49번길 49',
    '애월해안도로': '제주특별자치도 제주시 애월읍 애월리',
    '에코랜드테마파크': '제주특별자치도 제주시 조천읍 번영로 1278-169',
    '여미지식물원': '제주특별자치도 서귀포시 중문관광로 93',
    '오설록티뮤지엄': '제주특별자치도 서귀포시 안덕면 신화역사로 15',
    '우도봉': '제주특별자치도 제주시 우도면 연평리',
    '웅지승마센터': '제주특별자치도 제주시 애월읍 평화로 1529',
    '윈드1947카트테마파크': '제주특별자치도 서귀포시 토평동 3100-1',
    '이중섭미술관': '제주특별자치도 서귀포시 이중섭로 27-3',
    '일출랜드': '제주특별자치도 서귀포시 성산읍 중산간동로 4150-30',
    '절물자연휴양림': '제주특별자치도 제주시 명림로 584',
    '제주코코몽에코파크' : '제주특별자치도 서귀포시 안덕면 녹차분재로 218',
    '제주학생문화원': '제주특별자치도 제주시 연삼로 473',
    '제주항일기념관': '제주특별자치도 제주시 조천읍 남조로 89',
    '제주해양동물박물관': '제주특별자치도 서귀포시 안덕면 동광로 124'}

# %%
# Adding the remaining addresses to address_dict
address_dict.update({
    '제주4.3평화공원': '제주특별자치도 제주시 명림로 430',
    '제주4.3평화공원제주4.3평화기념관': '제주특별자치도 제주시 명림로 430',
    '제주곶자왈도립공원': '제주특별자치도 서귀포시 대정읍 에듀시티로 178',
    '제주국제평화센터': '제주특별자치도 서귀포시 중문관광로 227-24',
    '제주도립김창열미술관': '제주특별자치도 제주시 한림읍 용금로 883',
    '제주도립미술관': '제주특별자치도 제주시 1100로 2894-78',
    '제주돌문화공원': '제주특별자치도 제주시 조천읍 남조로 2023',
    '제주러브랜드': '제주특별자치도 제주시 1100로 2894-72',
    '제주민속촌': '제주특별자치도 서귀포시 표선면 민속해안로 631-34',
    '제주불빛정원': '제주특별자치도 제주시 애월읍 평화로 2346',
    '제주시민속오일시장': '제주특별자치도 제주시 오일장서길 26',
    '제주신화월드': '제주특별자치도 서귀포시 안덕면 신화역사로 304',
    '제주아트서커스': '제주특별자치도 서귀포시 안덕면 동광로 178-26',
    '제주영상문화산업진흥원': '제주특별자치도 제주시 첨단로 213-3',
    '제주월드컵경기장': '제주특별자치도 서귀포시 월드컵로 33',
    '제주종합경기장': '제주특별자치도 제주시 서광로2길 2',
    '제주차귀도요트투어': '제주특별자치도 제주시 한경면 고산리 125',
    '제주커피박물관바움': '제주특별자치도 서귀포시 성산읍 서성일로1168번길 89-17',
    '카멜리아힐' : '제주특별자치도 서귀포시 안덕면 상창리 557-3',
    '훈데르트바서파크' : '제주특별자치도 서귀포시 안덕면 산록남로 762',
    '제주항공우주박물관' : '제주특별자치도 서귀포시 안덕면 녹차분재로 218',
    '제주현대미술관' : '제주특별자치도 제주시 한경면 저지14길 35',
    'ICC제주국제컨벤션센터' : '제주특별자치도 서귀포시 중문관광로 224'
})

address_dict  # Displaying the updated dictionary for verification
# Out:
# {'9.81파크': '제주특별자치도 제주시 애월읍 천덕로 880-24',
#  '강창학종합경기장': '제주특별자치도 서귀포시 월드컵로 33',
#  '갤러리2중선농원': '제주특별자치도 제주시 애월읍 하가로 284',
#  '건강과성박물관': '제주특별자치도 서귀포시 상예로 178-19',
#  '고흐의정원': '제주특별자치도 서귀포시 안덕면 평화로 1100',
#  '교래자연휴양림': '제주특별자치도 제주시 조천읍 남조로 2023',
#  '국립제주박물관': '제주특별자치도 제주시 일주동로 17',
#  '국제리더스클럽': '제주특별자치도 제주시 연동 292-30',
#  '그리스신화박물관': '제주특별자치도 제주시 애월읍 평화로 990',
#  '금능석물원': '제주특별자치도 제주시 한림읍 금능남로 128',
#  '금능해수욕장': '제주특별자치도 제주시 한림읍 금능리 2036-1',
#  '기당미술관': '제주특별자치도 서귀포시 남성중로 27',
#  '김녕미로공원': '제주특별자치도 제주시 구좌읍 만장굴길 122',
#  '김녕요트투어': '제주특별자치도 제주시 구좌읍 김녕리 522-12',
#  '김녕해수욕장': '제주특별자치도 제주시 구좌읍 해맞이해안로 1012',
#  '김만덕기념관': '제주특별자치도 제주시 산지로 7',
#  '김영갑갤러리두모악': '제주특별자치도 서귀포시 성산읍 삼달로 137',
#  '남원큰엉해변': '제주특별자치도 서귀포시 남원읍 큰엉해안로',
#  '너븐숭이4.3기념관': '제주특별자치도 제주시 조천읍 북촌길 43',
#  '노형근린공원': '제주특별자치도 제주시 노형동 3793-2',
#  '대정현역사자료전시관': '제주특별자치도 서귀포시 대정읍 하모리 980-1',
#  '더마파크': '제주특별자치도 제주시 한림읍 월림7길 155',
#  '돌하르방미술관': '제주특별자치도 제주시 조천읍 남조로 2023',
#  '라온GC': '제주특별자치도 제주시 한림읍 금악리 1213',
# ...

# %%
df_combined['address'] = df_combined['place'].map(address_dict)

# %%
df_combined
# Out:
#     Unnamed: 0      place                            address  \
# 0            0     김녕해수욕장        제주특별자치도 제주시 구좌읍 해맞이해안로 1012
# 1            1   에코랜드테마파크       제주특별자치도 제주시 조천읍 번영로 1278-169
# 2            2      카멜리아힐         제주특별자치도 서귀포시 안덕면 상창리 557-3
# 3            3       섭지코지         제주특별자치도 서귀포시 성산읍 섭지코지로 107
# 4            4    절물자연휴양림                제주특별자치도 제주시 명림로 584
# ..         ...        ...                                ...
# 88         103  제주커피박물관바움  제주특별자치도 서귀포시 성산읍 서성일로1168번길 89-17
# 89         104  제주코코몽에코파크         제주특별자치도 서귀포시 안덕면 녹차분재로 218
# 90         105    제주학생문화원                제주특별자치도 제주시 연삼로 473
# 91         107    제주항일기념관             제주특별자치도 제주시 조천읍 남조로 89
# 92         108  제주해양동물박물관           제주특별자치도 서귀포시 안덕면 동광로 124
#
#                                description  \
# 0           에메랄드빛 바다가 펼쳐진 제주 동부의 아름다운 해수욕장
# 1   제주의 숲 속에서 기차를 타고 자연을 탐방할 수 있는 테마파크입니다.
# 2                    수많은 동백꽃이 아름답게 피어나는 정원
# 3              드넓은 바다와 초원이 펼쳐진 제주도의 명소입니다.
# ...

# %%
df_combined.isna()
# Out:
#     Unnamed: 0  place  address  description   link  photo
# 0        False  False    False        False  False  False
# 1        False  False    False        False  False  False
# 2        False  False    False        False  False  False
# 3        False  False    False        False  False  False
# 4        False  False    False        False  False  False
# ..         ...    ...      ...          ...    ...    ...
# 88       False  False    False        False  False  False
# 89       False  False    False        False  False  False
# 90       False  False    False        False  False  False
# 91       False  False    False        False  False  False
# 92       False  False    False        False  False  False
#
# [93 rows x 6 columns]

# %%
# Create a dictionary with place names as keys and their corresponding links (either official or review) as values
links_dict = {
    '강창학종합경기장': 'https://brunch.co.kr/@hongjina/26',
    '갤러리2중선농원': 'https://happy.designhouse.co.kr/magazine/magazine_view/00010005/5812',
    '국제리더스클럽': 'https://www.tripadvisor.co.kr/Attraction_Review-g297885-d12335286-Reviews-International_Leaders_Club-Jeju_Jeju_Island.html',
    '금능석물원': 'https://www.jejunolda.com/place/place.htm?act=view&seq=131',
    '금능해수욕장': 'https://blog.naver.com/PostView.nhn?blogId=jeju&logNo=221028123456',
    '노형근린공원': 'https://blog.naver.com/PostView.nhn?blogId=jeju&logNo=221028123789',
    '대정현역사자료전시관': 'https://blog.naver.com/PostView.nhn?blogId=jeju&logNo=221028124012',
    '새별프렌즈': 'https://www.jejunolda.com/place/place.htm?act=view&seq=201',
    '수목원테마파크아이스뮤지엄': 'https://blog.naver.com/PostView.nhn?blogId=jeju&logNo=221028124345',
    '스카이워터쇼': 'https://www.jejunolda.com/place/place.htm?act=view&seq=202'
}

links_dict  # Displaying the dictionary for verification
df_combined['link'] = df_combined['place'].map(links_dict)

# %%
# Creating a dictionary with place names as keys and their descriptions as values
descriptions_dict = {
    '제주코코몽에코파크': '코코몽과 함께하는 어린이 친화적인 테마파크로, 자연 속에서 놀이와 학습을 동시에 즐길 수 있는 다양한 체험 공간을 제공합니다. 친환경적인 요소와 놀이기구가 결합된 공간으로 가족 여행에 적합한 명소입니다.',
    '제주학생문화원': '제주 지역 학생들의 문화와 예술을 장려하기 위한 교육 및 체험의 장으로, 다양한 문화 예술 행사와 공연이 열리는 장소입니다. 학생들을 위한 전시와 공연 프로그램이 운영되며, 교육적 목적을 가진 공간입니다.',
    '제주항일기념관': '일제강점기 동안 독립운동을 펼친 제주인의 활동을 기리고자 설립된 기념관으로, 항일운동과 관련된 유물과 자료를 전시하고 있습니다. 제주 역사의 중요한 부분을 조명하며, 애국 정신을 기릴 수 있는 공간입니다.',
    '제주해양동물박물관': '제주 바다 생태계를 중심으로 다양한 해양 동물과 관련된 전시물을 소개하는 박물관입니다. 해양 생태계에 대한 교육적 정보와 함께 다양한 수족관이 마련되어 있어, 가족 단위 방문객들에게 인기를 끌고 있습니다.'
}

df_combined['description'] = df_combined['place'].map(descriptions_dict)
df_combined['Unnamed: 0'] = range(1, len(df_combined) + 1)

# %%
df_combined
# Out:
#     Unnamed: 0      place                            address  \
# 0            1     김녕해수욕장        제주특별자치도 제주시 구좌읍 해맞이해안로 1012
# 1            2   에코랜드테마파크       제주특별자치도 제주시 조천읍 번영로 1278-169
# 2            3      카멜리아힐         제주특별자치도 서귀포시 안덕면 상창리 557-3
# 3            4       섭지코지         제주특별자치도 서귀포시 성산읍 섭지코지로 107
# 4            5    절물자연휴양림                제주특별자치도 제주시 명림로 584
# ..         ...        ...                                ...
# 88          89  제주커피박물관바움  제주특별자치도 서귀포시 성산읍 서성일로1168번길 89-17
# 89          90  제주코코몽에코파크         제주특별자치도 서귀포시 안덕면 녹차분재로 218
# 90          91    제주학생문화원                제주특별자치도 제주시 연삼로 473
# 91          92    제주항일기념관             제주특별자치도 제주시 조천읍 남조로 89
# 92          93  제주해양동물박물관           제주특별자치도 서귀포시 안덕면 동광로 124
#
#                                           description link          photo
# 0                                                 NaN  NaN  data_1/01.jpg
# 1                                                 NaN  NaN  data_1/02.jpg
# ...

# %%
import shutil
import os

# 원본 파일 경로
source_file = 'C:\\Workspaces\\mini2\\minha\\data_2\\11.jpg'
# 복제본을 저장할 폴더 경로
destination_folder = 'path/to/destination_folder'
# 복제 횟수 설정
num_copies = 5
