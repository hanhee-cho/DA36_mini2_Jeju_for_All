# %%
import streamlit as st
import pandas as pd

# %%
data = {
    'FCLTY_NM': ['김녕해수욕장', '에코랜드테마파크', '카멜리아힐', '섭지코지', '절물자연휴양림',
                 '9.81파크', '훈데르트바서파크', '선녀와나무꾼테마공원', '서프라이즈테마파크', '더마파크'],
    'photo': ['data_1/01.jpg', 'data_1/02.jpg', 'data_1/03.jpg', 'data_1/04.jpg', 'data_1/05.jpg',
              'data_1/06.jpg', 'data_1/07.jpg', 'data_1/08.jpg', 'data_1/09.jpg', 'data_1/10.jpg'],
    'description': ['김녕해수욕장 설명', '에코랜드테마파크 설명', '카멜리아힐 설명', '섭지코지 설명', '절물자연휴양림 설명',
                    '9.81파크 설명', '훈데르트바서파크 설명', '선녀와나무꾼테마공원 설명', '서프라이즈테마파크 설명', '더마파크 설명']
}
df=pd.DataFrame(data)
df
# Out:
#      FCLTY_NM          photo    description
# 0      김녕해수욕장  data_1/01.jpg      김녕해수욕장 설명
# 1    에코랜드테마파크  data_1/02.jpg    에코랜드테마파크 설명
# 2       카멜리아힐  data_1/03.jpg       카멜리아힐 설명
# 3        섭지코지  data_1/04.jpg        섭지코지 설명
# 4     절물자연휴양림  data_1/05.jpg     절물자연휴양림 설명
# 5      9.81파크  data_1/06.jpg      9.81파크 설명
# 6    훈데르트바서파크  data_1/07.jpg    훈데르트바서파크 설명
# 7  선녀와나무꾼테마공원  data_1/08.jpg  선녀와나무꾼테마공원 설명
# 8   서프라이즈테마파크  data_1/09.jpg   서프라이즈테마파크 설명
# 9        더마파크  data_1/10.jpg        더마파크 설명

# %%
data = {
    'place': ['김녕해수욕장', '에코랜드테마파크', '카멜리아힐', '섭지코지', '절물자연휴양림',
                 '9.81파크', '훈데르트바서파크', '선녀와나무꾼테마공원', '서프라이즈테마파크', '더마파크',
                 '김만덕기념관', '그리스신화박물관', '국립제주박물관', '너븐숭이4.3기념관', '제주항공우주박물관',
                 '제주도립미술관', '제주현대미술관', 'ICC제주국제컨벤션센터', '남원큰엉해변', '선녀와나무꾼테마공원'],
    'photo': ['data_1/01.jpg', 'data_1/02.jpg', 'data_1/03.jpg', 'data_1/04.jpg', 'data_1/05.jpg',
              'data_1/06.jpg', 'data_1/07.jpg', 'data_1/08.jpg', 'data_1/09.jpg', 'data_1/10.jpg',
              'data_2/01.jpg', 'data_2/02.jpg', 'data_2/03.jpg', 'data_2/04.jpg', 'data_2/05.jpg',
              'data_2/06.jpg', 'data_2/07.jpg', 'data_2/08.jpg', 'data_2/09.jpg', 'data_2/10.jpg'],
    'description': ['에메랄드빛 바다가 펼쳐진 제주 동부의 아름다운 해수욕장', '제주 숲 속 기차여행을 즐길 수 있는 자연 테마파크', '수많은 동백꽃이 아름답게 피어나는 정원', '제주의 동쪽 해안 절경을 감상할 수 있는 명소', '숲 속에서의 힐링을 즐길 수 있는 자연휴양림',
                    '주에서 즐기는 레이싱과 익스트림 스포츠의 천국', '예술과 자연이 어우러진 독특한 건축물과 정원', '옛 제주 생활 문화를 체험할 수 있는 테마파크', '다양한 체험과 볼거리가 있는 가족 테마파크', '말과 함께하는 이색적인 체험 공간',
                    '제주 역사 속 김만덕의 삶과 정신을 기리는 기념관', '그리스 신화 속 이야기와 작품을 전시하는 박물관', '제주도의 역사와 문화를 만날 수 있는 국립 박물관', '제주 4.3 사건을 기리는 역사 기념관', '항공과 우주에 관한 다양한 전시와 체험을 제공하는 박물관',
                    '제주도 예술 작품들을 감상할 수 있는 미술관', '현대 예술 작품들이 전시된 독특한 미술 공간', '국제회의와 행사들이 열리는 컨벤션센터', '제주의 아름다운 바위와 절벽이 어우러진 해변', '제주 전통과 옛 생활을 체험할 수 있는 테마공원'],
  'link': ['https://www.visitjeju.net/kr/detail/view?contentsid=CONT_000000000500083', 'https://www.ecolandjeju.co.kr/', 'https://www.camelliahill.co.kr/',
             'https://www.visitjeju.net/kr/detail/view?contentsid=CONT_000000000500343', 'https://jeolmul.foresttrip.go.kr', 'https://www.981park.com/',
             'http://www.hundertwasserpark.co.kr/', 'https://www.visitjeju.net/kr/detail/view?contentsid=CONT_000000000500077&menuId=DOM_000001917007000000', 'https://www.surprisethemepark.com/',
             'https://www.bing.com/search?form=ANLKDR&q=themapark', 'http://www.mandukmuseum.or.kr/', 'http://www.greekmythology.co.kr/default/',
             'https://jeju.museum.go.kr/html/kr/', 'https://jeju43peace.or.kr/kor/sub05_01.do', 'https://www.jdc-jam.com/main.do',
             'https://www.jeju.go.kr/jmoa/', 'https://pkbiz.co.kr/', 'http://iccjeju.co.kr/main/main.php',
             'https://www.visitjeju.net/kr/detail/view?contentsid=CNTS_000000000019750', 'https://www.visitjeju.net/kr/detail/view?contentsid=CONT_000000000500077&menuId=DOM_000001917007000000']
}

df = pd.DataFrame(data)

# %%
df
# Out:
#            place          photo                      description  \
# 0         김녕해수욕장  data_1/01.jpg   에메랄드빛 바다가 펼쳐진 제주 동부의 아름다운 해수욕장
# 1       에코랜드테마파크  data_1/02.jpg     제주 숲 속 기차여행을 즐길 수 있는 자연 테마파크
# 2          카멜리아힐  data_1/03.jpg            수많은 동백꽃이 아름답게 피어나는 정원
# 3           섭지코지  data_1/04.jpg        제주의 동쪽 해안 절경을 감상할 수 있는 명소
# 4        절물자연휴양림  data_1/05.jpg         숲 속에서의 힐링을 즐길 수 있는 자연휴양림
# 5         9.81파크  data_1/06.jpg        주에서 즐기는 레이싱과 익스트림 스포츠의 천국
# 6       훈데르트바서파크  data_1/07.jpg         예술과 자연이 어우러진 독특한 건축물과 정원
# 7     선녀와나무꾼테마공원  data_1/08.jpg        옛 제주 생활 문화를 체험할 수 있는 테마파크
# 8      서프라이즈테마파크  data_1/09.jpg          다양한 체험과 볼거리가 있는 가족 테마파크
# 9           더마파크  data_1/10.jpg               말과 함께하는 이색적인 체험 공간
# 10        김만덕기념관  data_2/01.jpg      제주 역사 속 김만덕의 삶과 정신을 기리는 기념관
# 11      그리스신화박물관  data_2/02.jpg       그리스 신화 속 이야기와 작품을 전시하는 박물관
# 12       국립제주박물관  data_2/03.jpg      제주도의 역사와 문화를 만날 수 있는 국립 박물관
# ...

# %%
df = pd.DataFrame(data)
df.to_csv('data/df.csv')

# %%
df
# Out:
#            place          photo                      description  \
# 0         김녕해수욕장  data_1/01.jpg   에메랄드빛 바다가 펼쳐진 제주 동부의 아름다운 해수욕장
# 1       에코랜드테마파크  data_1/02.jpg     제주 숲 속 기차여행을 즐길 수 있는 자연 테마파크
# 2          카멜리아힐  data_1/03.jpg            수많은 동백꽃이 아름답게 피어나는 정원
# 3           섭지코지  data_1/04.jpg        제주의 동쪽 해안 절경을 감상할 수 있는 명소
# 4        절물자연휴양림  data_1/05.jpg         숲 속에서의 힐링을 즐길 수 있는 자연휴양림
# 5         9.81파크  data_1/06.jpg        주에서 즐기는 레이싱과 익스트림 스포츠의 천국
# 6       훈데르트바서파크  data_1/07.jpg         예술과 자연이 어우러진 독특한 건축물과 정원
# 7     선녀와나무꾼테마공원  data_1/08.jpg        옛 제주 생활 문화를 체험할 수 있는 테마파크
# 8      서프라이즈테마파크  data_1/09.jpg          다양한 체험과 볼거리가 있는 가족 테마파크
# 9           더마파크  data_1/10.jpg               말과 함께하는 이색적인 체험 공간
# 10        김만덕기념관  data_2/01.jpg      제주 역사 속 김만덕의 삶과 정신을 기리는 기념관
# 11      그리스신화박물관  data_2/02.jpg       그리스 신화 속 이야기와 작품을 전시하는 박물관
# 12       국립제주박물관  data_2/03.jpg      제주도의 역사와 문화를 만날 수 있는 국립 박물관
# ...

# %%
import pandas as pd

data = {
    'place': ['김녕해수욕장', '에코랜드테마파크', '카멜리아힐', '섭지코지', '절물자연휴양림',
              '9.81파크', '훈데르트바서파크', '선녀와나무꾼테마공원', '서프라이즈테마파크', '더마파크',
              '김만덕기념관', '그리스신화박물관', '국립제주박물관', '너븐숭이4.3기념관', '제주항공우주박물관',
              '제주도립미술관', '제주현대미술관', 'ICC제주국제컨벤션센터', '남원큰엉해변', '선녀와나무꾼테마공원'],
    'address': ['제주특별자치도 제주시 구좌읍 김녕리', '제주특별자치도 제주시 조천읍 남조로 2020', 
                '제주특별자치도 서귀포시 안덕면 상창리 557-3', '제주특별자치도 서귀포시 성산읍 섭지코지로',
                '제주특별자치도 제주시 한경면 절물로 168', '제주특별자치도 서귀포시 안덕면 창고길 27', 
                '제주특별자치도 제주시 한림읍 금능리 1961', '제주특별자치도 제주시 한림읍 귀덕리 370', 
                '제주특별자치도 제주시 한림읍 한림로 220', '제주특별자치도 서귀포시 색달로 213', 
                '제주특별자치도 제주시 도남로 53', '제주특별자치도 서귀포시 남원읍 태위로 407', 
                '제주특별자치도 제주시 일도2동 2490', '제주특별자치도 제주시 조천읍 4.3기념관로 55', 
                '제주특별자치도 서귀포시 대정읍 상모리 132', '제주특별자치도 제주시 연동 65', 
                '제주특별자치도 제주시 연동 57', '제주특별자치도 서귀포시 중문관광로 72', '제주특별자치도 서귀포시 남원읍 큰엉로','제주특별자치도 제주시 특별자치도, 조천읍 선교로 267'],
    'description': ['에메랄드빛 바다가 펼쳐진 제주 동부의 아름다운 해수욕장', '제주 숲 속 기차여행을 즐길 수 있는 자연 테마파크', '수많은 동백꽃이 아름답게 피어나는 정원', '제주의 동쪽 해안 절경을 감상할 수 있는 명소', '숲 속에서의 힐링을 즐길 수 있는 자연휴양림',
                    '제주에서 즐기는 레이싱과 익스트림 스포츠의 천국', '예술과 자연이 어우러진 독특한 건축물과 정원', '옛 제주 생활 문화를 체험할 수 있는 테마파크', '다양한 체험과 볼거리가 있는 가족 테마파크', '말과 함께하는 이색적인 체험 공간',
                    '제주 역사 속 김만덕의 삶과 정신을 기리는 기념관', '그리스 신화 속 이야기와 작품을 전시하는 박물관', '제주도의 역사와 문화를 만날 수 있는 국립 박물관', '제주 4.3 사건을 기리는 역사 기념관', '항공과 우주에 관한 다양한 전시와 체험을 제공하는 박물관',
                    '제주도 예술 작품들을 감상할 수 있는 미술관', '현대 예술 작품들이 전시된 독특한 미술 공간', '국제회의와 행사들이 열리는 컨벤션센터', '제주의 아름다운 바위와 절벽이 어우러진 해변', '제주 전통과 옛 생활을 체험할 수 있는 테마공원'],
    'link': ['https://www.visitjeju.net/kr/detail/view?contentsid=CONT_000000000500083', 'https://www.ecolandjeju.co.kr/', 'https://www.camelliahill.co.kr/',
             'https://www.visitjeju.net/kr/detail/view?contentsid=CONT_000000000500343', 'https://jeolmul.foresttrip.go.kr', 'https://www.981park.com/',
             'http://www.hundertwasserpark.co.kr/', 'https://www.visitjeju.net/kr/detail/view?contentsid=CONT_000000000500077&menuId=DOM_000001917007000000', 'https://www.surprisethemepark.com/',
             'https://www.mapark.co.kr/', 'http://www.mandukmuseum.or.kr/', 'http://www.greekmythology.co.kr/default/',
             'https://jeju.museum.go.kr/html/kr/', 'https://jeju43peace.or.kr/kor/sub05_01.do', 'https://www.jdc-jam.com/main.do',
             'https://www.jeju.go.kr/jmoa/', 'https://pkbiz.co.kr/', 'http://iccjeju.co.kr/main/main.php',
             'https://www.visitjeju.net/kr/detail/view?contentsid=CNTS_000000000019750', 'https://www.visitjeju.net/kr/detail/view?contentsid=CONT_000000000500077&menuId=DOM_000001917007000000'],
    'photo': ['data_1/01.jpg', 'data_1/02.jpg', 'data_1/03.jpg', 'data_1/04.jpg', 'data_1/05.jpg',
              'data_1/06.jpg', 'data_1/07.jpg', 'data_1/08.jpg', 'data_1/09.jpg', 'data_1/10.jpg',
              'data_2/01.jpg', 'data_2/02.jpg', 'data_2/03.jpg', 'data_2/04.jpg', 'data_2/05.jpg',
              'data_2/06.jpg', 'data_2/07.jpg', 'data_2/08.jpg', 'data_2/09.jpg', 'data_2/10.jpg'],
}

df = pd.DataFrame(data)
df
# Out:
#            place                         address  \
# 0         김녕해수욕장             제주특별자치도 제주시 구좌읍 김녕리
# 1       에코랜드테마파크        제주특별자치도 제주시 조천읍 남조로 2020
# 2          카멜리아힐      제주특별자치도 서귀포시 안덕면 상창리 557-3
# 3           섭지코지          제주특별자치도 서귀포시 성산읍 섭지코지로
# 4        절물자연휴양림         제주특별자치도 제주시 한경면 절물로 168
# 5         9.81파크         제주특별자치도 서귀포시 안덕면 창고길 27
# 6       훈데르트바서파크        제주특별자치도 제주시 한림읍 금능리 1961
# 7     선녀와나무꾼테마공원         제주특별자치도 제주시 한림읍 귀덕리 370
# 8      서프라이즈테마파크         제주특별자치도 제주시 한림읍 한림로 220
# 9           더마파크            제주특별자치도 서귀포시 색달로 213
# 10        김만덕기념관              제주특별자치도 제주시 도남로 53
# 11      그리스신화박물관        제주특별자치도 서귀포시 남원읍 태위로 407
# 12       국립제주박물관           제주특별자치도 제주시 일도2동 2490
# 13    너븐숭이4.3기념관      제주특별자치도 제주시 조천읍 4.3기념관로 55
# 14     제주항공우주박물관        제주특별자치도 서귀포시 대정읍 상모리 132
# 15       제주도립미술관               제주특별자치도 제주시 연동 65
# 16       제주현대미술관               제주특별자치도 제주시 연동 57
# 17  ICC제주국제컨벤션센터           제주특별자치도 서귀포시 중문관광로 72
# ...

# %%
df.to_csv('data/df.csv')

# %%
check=pd.read_csv('data/df.csv')
check
# Out:
#     Unnamed: 0         place                         address  \
# 0            0        김녕해수욕장             제주특별자치도 제주시 구좌읍 김녕리
# 1            1      에코랜드테마파크        제주특별자치도 제주시 조천읍 남조로 2020
# 2            2         카멜리아힐      제주특별자치도 서귀포시 안덕면 상창리 557-3
# 3            3          섭지코지          제주특별자치도 서귀포시 성산읍 섭지코지로
# 4            4       절물자연휴양림         제주특별자치도 제주시 한경면 절물로 168
# 5            5        9.81파크         제주특별자치도 서귀포시 안덕면 창고길 27
# 6            6      훈데르트바서파크        제주특별자치도 제주시 한림읍 금능리 1961
# 7            7    선녀와나무꾼테마공원         제주특별자치도 제주시 한림읍 귀덕리 370
# 8            8     서프라이즈테마파크         제주특별자치도 제주시 한림읍 한림로 220
# 9            9          더마파크            제주특별자치도 서귀포시 색달로 213
# 10          10        김만덕기념관              제주특별자치도 제주시 도남로 53
# 11          11      그리스신화박물관        제주특별자치도 서귀포시 남원읍 태위로 407
# 12          12       국립제주박물관           제주특별자치도 제주시 일도2동 2490
# 13          13    너븐숭이4.3기념관      제주특별자치도 제주시 조천읍 4.3기념관로 55
# ...
